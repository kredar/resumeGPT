# %% [markdown]
# # App Review Analysis using Open AI API
#
#
# ## Introduction
#
# This Jupyter notebook is an atempt to use LLMs for Topic mining and google app review analysis.
#
#
# ## Setup
#
# This notebook was created using [Python version] and the following packages:
#
# - google_play_scraper
# - pandas
# - numpy
# - openai
# - json
# - os
#
# To run this notebook, please make sure you have these packages installed.
#
# ## Author
#
# Art Kreimer
# [LinkedIn](https://www.linkedin.com/in/artkreimer/)
# [Personal Blog](https://www.artkreimer.com/)

# %%
import pandas as pd
import numpy as np
import json
import os
import openai
import time
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import json
#       4 import os
# ----> 5 import openai
#       6 import time
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'openai'

# %%
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
# First lets use the scraper to get all Google App reviews
#
reviews_df=pd.read_csv('~/Downloads/app_reviews_data_02052023.csv')


from google_play_scraper import app,Sort, reviews_all
all_reviews = reviews_all(
    'ca.tangerine.clients.banking.app',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='ca', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)
df_reviews = pd.DataFrame(np.array(all_reviews),columns=['review'])
df_reviews = df_reviews.join(pd.DataFrame(df_reviews.pop('review').tolist()))
df_reviews['at'] = df_reviews['at'].astype(str)
df_reviews.head()
# Out:
#                                reviewId       userName  \
# 0  0e927561-1136-4477-a336-1214a05aac80      Mackenzie
# 1  ef534040-3981-44e5-bd96-b5e07f954f1b        Jie Lin
# 2  48f21b98-074b-451e-a5d5-4cc0ab8779c7      sugarkats
# 3  544c47b3-fd40-4847-b649-8dc7282865fd   Paige Stacey
# 4  71bc9909-4b57-4a45-814e-e23b9cff0072  Marika Wagner
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Should list your apps active service hours. Li...      3              0
# 1            You need to support Face ID for Pixel 4      1              0
# 2  Works perfectly and fluidly just like the webs...      5              1
# 3  I recommend this banking app to anyone who ask...      5              0
# 4                              excellent banking app      5              0
#
#   reviewCreatedVersion                   at  \
# 0               4.31.1  2023-10-21 03:45:26
# 1               4.31.1  2023-10-20 10:40:36
# 2               4.31.1  2023-10-19 13:46:35
# 3               4.29.3  2023-10-18 16:12:30
# 4               4.29.3  2023-10-16 15:25:16
#
#                          replyContent           repliedAt appVersion
# 0                                None                 NaT     4.31.1
# 1                                None                 NaT     4.31.1
# 2  Thank you so much for your review! 2021-01-19 16:25:14     4.31.1
# 3                                None                 NaT     4.29.3
# 4                                None                 NaT     4.29.3

# %%
df_reviews.groupby(['score']).agg({'score':['count']})
df_reviews[0:200].groupby(['score']).agg({'score':['count']})
df_reviews.groupby(['year','month']).agg({'score':['mean']}).plot.line()
df_reviews[(df_reviews['score']<4 ) & 
           (df_reviews['year']>2020)].groupby(['year','month']).agg({'repliedbool':['mean']}).plot.line(figsize=(10,10))
df_reviews.groupby(['year','month']).agg({'score':['mean']}).plot.line()
df_reviews_2021_2022.groupby(['year','month']).agg({'score':['count','mean']})#.plot.line(figsize=(15, 15))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/artiom/Documents/python_projects/git/data_analytics/android_reviews_app/reviews_analysis_openai.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/Users/artiom/Documents/python_projects/git/data_analytics/android_reviews_app/reviews_analysis_openai.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> df_reviews.groupby(['score']).agg({'score':['count']})
#       <a href='vscode-notebook-cell:/Users/artiom/Documents/python_projects/git/data_analytics/android_reviews_app/reviews_analysis_openai.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> df_reviews[0:200].groupby(['score']).agg({'score':['count']})
# ----> <a href='vscode-notebook-cell:/Users/artiom/Documents/python_projects/git/data_analytics/android_reviews_app/reviews_analysis_openai.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> df_reviews.groupby(['year','month']).agg({'score':['mean']}).plot.line()
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'year'

# %%
#this is a helper function to call OpenAI API. 
#I am using gpt-3.5-turbo model for this analysis

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
df_reviews.head()
col_name="userName"
col_review="content"
# let's take last 100 app reviews with rating below 4 stars
last_100_negative_reviews_df=df_reviews[df_reviews['score']<4][0:100]

# %%
last_100_negative_reviews_df.head()
# Out:
#                                reviewId       userName  \
# 0  0e927561-1136-4477-a336-1214a05aac80      Mackenzie
# 1  ef534040-3981-44e5-bd96-b5e07f954f1b        Jie Lin
# 5  998711e2-6b40-4af6-982a-992f8abfa9c7  Jessica Smith
# 6  ad712d40-1787-407a-845d-be73122b0da6  John Davidson
# 9  91f6eb48-4db3-488b-80f2-4bfdf7892405       Shadow C
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 5  https://play-lh.googleusercontent.com/a/ACg8oc...
# 6  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  Should list your apps active service hours. Li...      3              0
# 1            You need to support Face ID for Pixel 4      1              0
# 5  Too much stress figuring out if I can open an ...      1              0
# 6  If anyone is wanting to open an account with t...      1              0
# 9  Laggy, bloated, cumbersome use flow. As good a...      1              1
#
#   reviewCreatedVersion                   at replyContent repliedAt appVersion
# 0               4.31.1  2023-10-21 03:45:26         None       NaT     4.31.1
# 1               4.31.1  2023-10-20 10:40:36         None       NaT     4.31.1
# 5               4.29.3  2023-10-15 11:15:12         None       NaT     4.29.3
# 6               4.29.3  2023-10-14 11:17:13         None       NaT     4.29.3
# 9               4.31.1  2023-10-13 10:20:34         None       NaT     4.31.1

# %%
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");



product_stopwords = {}
#{"products","skill","skills","will","day","is",\
#"this","role","right","for","product","you","experience", "minimum", "digital","scotia"}


text = ' '.join(last_100_negative_reviews_df['content'].astype(str).values)

#text=' '.join([' '.join(ele) for ele in last_100_reviews_df['content']])

STOPWORDS=STOPWORDS.union(product_stopwords)

# Generate word cloud
wordcloud = WordCloud(width= 3000, height = 2000, random_state=1, 
                      background_color='salmon', colormap='Pastel1', 
                      collocations=False, stopwords = STOPWORDS).generate(text)
# Plot
plot_cloud(wordcloud)

# %%
# I want to detect the following using openai api
last_100_negative_reviews_df['summary']=''
last_100_negative_reviews_df['sentiment']=''
last_100_negative_reviews_df['emotions']=''
last_100_negative_reviews_df['anger']=''
last_100_negative_reviews_df['frustration']=''
last_100_negative_reviews_df['topics']=''
last_100_negative_reviews_df['review_response']=''

# %%
#Summarize the review using three keywords.
#Determine five topics that are being discussed in the review

# %%
for index, row in last_100_negative_reviews_df.iterrows():
    review=row['content']
    prompt = f"""\
Your task is to perform the following actions on the mobile app review delimited by triple backticks: 
1 - Summarize with 1 sentence.
2 - Determine the sentiment of the review 
3 - Identify a list of emotions in the review. Include no more than \
five items in the list. Format your answer as a list of \
lower-case words separated by commas.
4 - Identify if the writer of the app review expressing anger?
5 - Identify if the writer of the app review expressing frustration?
6 - Summarize the review using two words, but don't use the following keywords 'bank', 'banking', 'app',  \

Output a json object only that contains the following keys: \ 
summary, sentiment, emotions, anger as a boolean, frustration as boolean, topics.\
  Make sure output is a valid json format

Review: ```{review}```
"""
    
    response = get_completion(prompt)
    print(response)
    response_json = json.loads(response)
   
    #time.sleep(2)
    last_100_negative_reviews_df.at[index, 'summary']=response_json['summary']
    last_100_negative_reviews_df.at[index, 'sentiment']=response_json['sentiment']
    last_100_negative_reviews_df.at[index, 'emotions']=response_json['emotions']
    last_100_negative_reviews_df.at[index, 'anger']=response_json['anger']
    last_100_negative_reviews_df.at[index, 'frustration']=response_json['frustration']
    last_100_negative_reviews_df.at[index, 'topics']=response_json['topics']
# Out:
# {
#   "summary": "Free app goes down randomly at night causing inconvenience to night shift workers.",
#   "sentiment": "negative",
#   "emotions": ["frustration", "inconvenience", "anger"],
#   "anger": true,
#   "frustration": true,
#   "topics": ["night shift", "random downtime", "inconvenience"]
# }
# {
#   "summary": "App maintenance prevents access to digital card for orders without warning.",
#   "sentiment": "negative",
#   "emotions": ["annoyed", "frustrated", "impatient"],
#   "anger": false,
#   "frustration": true,
#   "topics": ["orders", "maintenance", "access"]
# }
# {
#   "summary": "Lack of description for incoming deposits.",
#   "sentiment": "negative",
#   "emotions": ["frustration", "disappointment"],
#   "anger": false,
#   "frustration": true,
#   "topics": ["deposits", "statements"]
# }
# {
#   "summary": "App frequently freezes and needs updating.",
#   "sentiment": "negative",
#   "emotions": ["frustration"],
#   "anger": false,
#   "frustration": true,
#   "topics": ["login", "update"]
# }
# {
#   "summary": "Unable to open app after update and encountering bugs.",
#   "sentiment": "negative",
#   "emotions": ["frustration", "disappointment"],
#   "anger": false,
#   "frustration": true,
#   "topics": ["update", "bugs"]
# }
# {
# "summary": "Terrible bank with bad customer service and potential for theft.",
# "sentiment": "negative",
# "emotions": ["anger", "distrust", "fear"],
# "anger": true,
# "frustration": false,
# "topics": ["issues", "branch", "customer service", "lying", "theft"]
# }
# {
#   "summary": "The app is poor.",
#   "sentiment": "negative",
#   "emotions": ["disappointment"],
#   "anger": false,
#   "frustration": false,
#   "topics": ["improvement", "quality"]
# }
# {
# "summary": "Tangerine allowed a scammer to reverse a damage claim and took $206 from the writer.",
# "sentiment": "negative",
# "emotions": ["scammed", "angry", "frustrated"],
# "anger": true,
# "frustration": true,
# "topics": ["scam", "reversal"]
# }
# {
#   "summary": "The app is terrible.",
#   "sentiment": "negative",
#   "emotions": ["disappointment"],
#   "anger": false,
#   "frustration": false,
#   "topics": ["poor quality"]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/cq/40xd1c350qb48wl593nz7rjc0000gn/T/ipykernel_39447/1984747088.py in <module>
#      22 """
#      23
# ---> 24     response = get_completion(prompt)
#      25     print(response)
#      26     response_json = json.loads(response)
#
# /var/folders/cq/40xd1c350qb48wl593nz7rjc0000gn/T/ipykernel_39447/2212933055.py in get_completion(prompt, model)
#       4 def get_completion(prompt, model="gpt-3.5-turbo"):
#       5     messages = [{"role": "user", "content": prompt}]
# ----> 6     response = openai.ChatCompletion.create(
#       7         model=model,
#       8         messages=messages,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     214         request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215     ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 216         result = self.request_raw(
#     217             method.lower(),
#     218             url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     514             _thread_context.session = _make_session()
#     515         try:
# --> 516             result = _thread_context.session.request(
#     517                 method,
#     518                 abs_url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
last_100_negative_reviews_df.head()
last_100_negative_reviews_df.to_csv('~/Downloads/app_reviews_data_openai_last100_010623.csv')

# %%
#all_summaries = ' '.join([''.join(summary) for summary in last_100_reviews_df['summary']])
all_summaries = last_100_negative_reviews_df['topics'].values.tolist()

prompt = f"""\
you are a data analysist.\
You have received a lot of app reviews. 
Your task is to identify 20 most friequntly mentioned issues product team needs to fix \
from the mobile app review delimited by triple backticks\ 
You output should have one or two words to describe the issue and and the issue itself
```{all_summaries}```
"""
    
response = get_completion(prompt)
print(response)
# Out:
# 1. Night shift inconvenience
# 2. Orders maintenance
# 3. Descriptive statement
# 4. Update freeze
# 5. Update bugs
# 6. Customer service issues
# 7. Low-quality experience
# 8. Scam money
# 9. Poor experience
# 10. Security access modification
# 11. Fraud ESG initiatives
# 12. Slow loading screen
# 13. Unreliable app
# 14. Requesting money difficulty
# 15. Slow deposits
# 16. Transactions accuracy
# 17. Unusable update
# 18. Sign-in loading
# 19. Currency check deposit
# 20. Login limitations

# %%
last_100_negative_reviews_df[last_100_negative_reviews_df['frustration']!=True].head()
# Out:
#                                 reviewId         userName  \
# 15  fc5fbc6b-8d86-4721-aecf-6a01788d4268      Wayne Bruce
# 17  e11a6c3b-5e22-4e40-8096-c4eaa14170ab       Dani D.A.N
# 23  2b28dc65-e3a5-4f98-be27-94b0c649b1e7    tecca Glosser
# 31  18d72ec2-42bd-4053-a146-3a46b8d3735a     Remi Matlosz
# 81  4a632ca9-fb68-4134-891e-38eaa0ec4038  Joshua Elderton
#
#                                             userImage  \
# 15  https://play-lh.googleusercontent.com/a-/AD_cM...
# 17  https://play-lh.googleusercontent.com/a-/AD_cM...
# 23  https://play-lh.googleusercontent.com/a-/AD_cM...
# 31  https://play-lh.googleusercontent.com/a/AAcHTt...
# 81  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                               content  score  thumbsUpCount  \
# 15  One of the worst banks ever. Hope you don't ha...      1              0
# 17                                               poor      2              0
# 23                       Just terrible I've ever been      1              0
# 31  Working directly with the Far-left Canadian co...      1              0
# 81                 horrible experience with this bank      1              0
#
#    reviewCreatedVersion                   at replyContent repliedAt  \
# 15               4.26.1  2023-05-16 16:20:07         None       NaT
# 17               4.26.1  2023-05-16 00:57:53         None       NaT
# 23               4.13.0  2023-05-14 13:45:44         None       NaT
# 31               4.26.1  2023-05-09 18:29:28         None       NaT
# 81               4.25.0  2023-03-31 19:28:18         None       NaT
#
#                                               summary sentiment  \
# 15                   A negative review of a bank app.  negative
# 17              The review is too short to summarize.  negative
# 23                               The app is terrible.  negative
# 31  The review expresses negative sentiment toward...  negative
# 81                     Negative review of a bank app.  negative
#
#                             emotions  anger frustration  \
# 15  [anger, distrust, fear, disgust]   True       False
# 17                  [disappointment]  False       False
# 23                  [disappointment]  False       False
# 31                  [anger, disgust]   True       False
# 81                         [disgust]   True       False
#
#                                                topics review_response
# 15  [banking, customer service, trust, money, secu...
# 17                                          [quality]
# 23                                [app functionality]
# 31  [financial fraud, ESG initiatives, debanking, ...
# 81                                        [bank, app]

# %%
### Let's check what are the main topics about

# %%
from collections import Counter
 
 
def freq(str):
 
    # break the string into list of words
    str_list = str.split()
 
    frequency = Counter(str_list)
 
    for word in frequency.most_common():
        print( word)
freq(text)
# Out:
# ('app', 22)
# ('banking', 13)
# ('customer', 10)
# ('service', 9)
# ('security', 8)
# ('update', 7)
# ('login', 7)
# ('account', 7)
# ('card', 6)
# ('money', 6)
# ('transactions', 6)
# ('loading', 5)
# ('fees', 5)
# ('bank', 5)
# ('issues', 4)
# ('scam', 4)
# ('access', 4)
# ('verification', 4)
# ('usability', 4)
# ('digital', 3)
# ('slow', 3)
# ('balance', 3)
# ('details', 3)
# ('website', 3)
# ('mobile', 3)
# ('support', 3)
# ('phone', 3)
# ('speed', 3)
# ('functionality', 3)
# ('experience', 2)
# ('fraud', 2)
# ('deposit', 2)
# ('times', 2)
# ('deposits', 2)
# ('check', 2)
# ('ID', 2)
# ('convenience', 2)
# ('search', 2)
# ('funds', 2)
# ('notifications', 2)
# ('quality', 2)
# ('credit', 2)
# ('interface', 2)
# ('transaction', 2)
# ('devices', 2)
# ('company', 2)
# ('performance', 2)
# ('available', 2)
# ('spending', 2)
# ('accounts', 2)
# ('night', 1)
# ('shift', 1)
# ('random', 1)
# ('downtime', 1)
# ('inconvenience', 1)
# ('orders', 1)
# ('maintenance', 1)
# ('descriptive', 1)
# ('incoming', 1)
# ('statement', 1)
# ('freeze', 1)
# ('bugs', 1)
# ('cache', 1)
# ('branch', 1)
# ('low-quality', 1)
# ('unsatisfactory', 1)
# ('disappointing', 1)
# ('reversal', 1)
# ('poor', 1)
# ('worst', 1)
# ('modification', 1)
# ('ESG', 1)
# ('initiatives', 1)
# ("Canada's", 1)
# ('interests', 1)
# ('opening', 1)
# ('screen', 1)
# ('unreliable', 1)
# ('difficult', 1)
# ('requesting', 1)
# ('long', 1)
# ('difficulty', 1)
# ('late', 1)
# ('data', 1)
# ('accuracy', 1)
# ('unusable', 1)
# ('sign-in', 1)
# ('currency', 1)
# ('Pixel', 1)
# ('4XL', 1)
# ('Face', 1)
# ('problems', 1)
# ('void', 1)
# ('PDF', 1)
# ('display', 1)
# ('overdraft', 1)
# ('developers', 1)
# ('fix', 1)
# ('lock', 1)
# ('essential', 1)
# ('feature', 1)
# ('missing', 1)
# ('limited', 1)
# ('options', 1)
# ('PO', 1)
# ('box', 1)
# ('address', 1)
# ('delayed', 1)
# ('high', 1)
# ('confirm', 1)
# ('repeatedly', 1)
# ('same', 1)
# ('page', 1)
# ('pin', 1)
# ('reset', 1)
# ('transfer', 1)
# ('limitations', 1)
# ('user', 1)
# ('features', 1)
# ('NSF', 1)
# ('outdated', 1)
# ('system', 1)
# ('pending', 1)
# ('cards', 1)
# ('chat', 1)
# ('human', 1)
# ('agent', 1)
# ('changing', 1)
# ('banks', 1)
# ('latency', 1)
# ('architecture', 1)
# ('cheques', 1)
# ('missed', 1)
# ('payments', 1)
# ('deactivation', 1)
# ('cancellation', 1)
# ('confirmation', 1)
# ('process', 1)
# ('PC', 1)
# ('activation', 1)
# ('stuck', 1)
# ('charged', 1)
# ('Google', 1)
# ('advertising', 1)
# ('tracker', 1)
# ('blocking', 1)
# ('attempts', 1)
# ('differences', 1)
# ('password', 1)
# ('third', 1)
# ('party', 1)
# ('Well', 1)
# ('wishes', 1)
# ('two-step', 1)
# ('closing', 1)
# ('Tangerine', 1)
# ('history', 1)
# ('PayPal', 1)
# ('unposted', 1)
# ('entries', 1)
# ('Scotia', 1)
# ('light', 1)
# ('upgrading', 1)
# ('updates', 1)
# ('two', 1)
# ('factor', 1)
# ('text', 1)
# ('traveling', 1)
# ('cell', 1)
# ('signal', 1)
# ('wait', 1)
# ('technical', 1)
# ('glitches', 1)
# ('prevention', 1)
# ('loss', 1)
# ('restart', 1)
# ('UI', 1)
# ('habits', 1)
# ('pie', 1)
# ('graphs', 1)
# ('budget', 1)
# ('legacy', 1)
# ('setting', 1)
# ('design', 1)
# ('interest', 1)
# ('rates', 1)
# ('reputation', 1)
# ('lawsuit', 1)
# ('employee', 1)
# ('compensation', 1)
# ('authentication', 1)
# ('usage', 1)
# ('turning', 1)
# ('off', 1)
# ('cheque', 1)
# ('holds', 1)
# ('validation', 1)
# ('info', 1)
# ('2FA', 1)
# ('SMS', 1)
# ('codes', 1)
# ('rooted', 1)
# ('phones', 1)
# ('incompatibility', 1)
# ('servers', 1)
# ('fingerprint', 1)
# ('recognition', 1)
# ('settings', 1)
# ('email', 1)
# ('installation', 1)
# ('changes', 1)
# ('navigation', 1)
# ('joint', 1)
# ('recommendation', 1)

# %%
product_stopwords = {}
#{"products","scotiabank","skill","skills","will","day","is","this","role","right","for","product","you","experience", "minimum", "digital","scotia"}


# text = df_jan['content'].astype(str).values 

text=' '.join([' '.join(ele) for ele in last_100_negative_reviews_df['emotions']])

STOPWORDS=STOPWORDS.union(product_stopwords)

# Generate word cloud
wordcloud = WordCloud(width= 3000, height = 2000, random_state=1, 
                      background_color='salmon', colormap='Pastel1', 
                      collocations=False, stopwords = STOPWORDS).generate(text)
# Plot
plot_cloud(wordcloud)

# %%
# Create a training data based on reviews and responses. We took 5 examples 
responses_training_prompt=''
for index, row in df_reviews[df_reviews['repliedAt'].astype(str)!='NaT'][0:5].iterrows():
    prompt=f"""name:{row['userName']} review:{row['content']} response:{row['replyContent']}"""
    responses_training_prompt+=" "+prompt

    
print(responses_training_prompt)
# Out:
#  name:S. Crépeault review:Can't open this app anymore after the last update. Tried cleaning the cache. Another bug like last week. Can't open the app. response:Hi, we're really sorry about this. We request you to write to us on mobile.feedback@tangerine.ca with your Orange Key, as it will help us diagnose the root cause. You should be able to find your Orange Key by logging in to tangerine.ca > Side menu > Profile & Settings > General > Refer a Friend. name:Zack S review:Whenever I filter my transactions for February, it gives me March's transactions. When I filter for transactions in the current month (at the end of the month) it tells me I have no transactions for that month (which is false). This doesn't inspire confidence that it can't pull data up properly. Particularly when I'm seeing that the numbers in my account don't seem to be adding up. response:Hi Zack, we're sorry about this. Request you to write to us on mobile.feedback@tangerine.ca with your Orange Key, and we'll continue the conversation further there. name:Craig Li review:Extremely slow app. My chequing and savings account page shows as loading. Only the credit card balance and transaction can be viewed. The latest update has made the app unusable. Il have to switch to desktop now... Thanks. response:Hi Craig, we're really sorry about this. Request you to write to us on mobile.feedback@tangerine.ca with your Orange Key, as this will help us diagnose the root cause of the issue. Thank you! name:Jason Litke review:The void check option opens a Google play store search for "pdf" instead of showing the actual void check for the selected account. ***No the app doesn't try to open the void check PDF in a PDF app, it opens a search for "pdf" in either the Google Play Store or F-Droid.*** response:Hi Jason, since the void check is in PDF format, the app tries to open a corresponding PDF Viewer installed on the phone. Could you check if a PDF Reader app like Adobe Acrobat Reader is already installed on your phone? If not, could you install it and try to open the void check again? If still no luck, write to us on mobile.feedback@tangerine.ca. name:tiff martin review:Just some feedback: on all accounts, except for credit card, it shows the new balance after every transaction. It would be great if that changed. Please. Between transactions, pending and payments I don't find it as easy to use as my other banks and so reach for it less response:Hi Tiff, really sorry about this. Could you email us on mobile.feedback@tangerine.ca with your Orange Key? That will help us diagnose what's going wrong better. Thank you!

# %%
freq(text)
# Out:
# Frequency of  inconvenience is : 1
# Frequency of  frustration is : 52
# Frequency of  anger is : 17
# Frequency of  disappointment is : 38
# Frequency of  hunger is : 1
# Frequency of  annoyed is : 1
# Frequency of  frustrated is : 3
# Frequency of  impatient is : 1
# Frequency of  confusion is : 7
# Frequency of  distrust is : 5
# Frequency of  fear is : 1
# Frequency of  disgust is : 5
# Frequency of  scammed is : 1
# Frequency of  angry is : 1
# Frequency of  impatience is : 5
# Frequency of  annoyance is : 2
# Frequency of  dissatisfaction is : 1
# Frequency of  disappointed is : 2
# Frequency of  minimalist is : 1
# Frequency of  suspicion is : 1
# Frequency of  concern is : 2
# Frequency of  incompetent is : 1
# Frequency of  dislike is : 1
# Frequency of  wondering is : 1

# %%
r
    
last_100_negative_reviews_df.to_csv('~/Downloads/app_reviews_data_openai_last100_010623.csv')
# Out:
# {
#   "response": "Hi Chris, we're sorry to hear about your experience. We understand how frustrating it can be when the app goes down unexpectedly. We assure you that our team is working hard to ensure that such incidents are minimized. If you could write to us on mobile.feedback@tangerine.ca with your Orange Key, we'll investigate the issue further and see how we can help. Thank you for your patience and understanding."
# }
# {
#     "response": "Hi Okuurrrt, we apologize for the inconvenience caused. We understand how frustrating it can be when you can't access your digital card during maintenance. We'll make sure to pass on your feedback to our team. Thank you for bringing this to our attention."
# }
# {
#   "response": "Hi Alex, thank you for your feedback. We understand the importance of having descriptive transaction details and we'll definitely take this into consideration for future updates. If you have any further concerns, please don't hesitate to reach out to us at mobile.feedback@tangerine.ca. Thank you!"
# }
# {
#   "response": "Hi Piotr, we apologize for the inconvenience caused. Could you please write to us on mobile.feedback@tangerine.ca with your Orange Key? This will help us diagnose the issue and provide a solution. Thank you for your patience."
# }
# {
#   "response": "Hi, we're really sorry about this. We request you to write to us on mobile.feedback@tangerine.ca with your Orange Key, as it will help us diagnose the root cause. You should be able to find your Orange Key by logging in to tangerine.ca > Side menu > Profile & Settings > General > Refer a Friend."
# }
# {
#   "response": "Hi Wayne, we're sorry to hear about your negative experience. We take all customer complaints seriously and would like to investigate this further. Could you please email us at mobile.feedback@tangerine.ca with more details about your issue and your Orange Key? We'll do our best to resolve this for you. Thank you."
# }
# {
#   "response": "Hi Dani, we're sorry to hear that. Could you please provide us with more details on what specifically you find poor about the app? We'd love to hear your feedback and suggestions on how we can improve. Please email us at mobile.feedback@tangerine.ca with your Orange Key. Thank you!"
# }
# {
#   "response": "Hi Mr Nobody, we're sorry to hear about your experience. We take fraud very seriously and would like to investigate this further. Could you please email us at mobile.feedback@tangerine.ca with your Orange Key and any additional details you have about the incident? Thank you."
# }
# {
#   "response": "Hi Tecca, we're sorry to hear that. Could you please provide us with more details on what went wrong so we can improve our app? You can email us at mobile.feedback@tangerine.ca. Thank you for your feedback."
# }
# {
#   "response": "Hi Jack, we apologize for the inconvenience. Our app requires a secure environment to protect your personal and financial information. Unfortunately, we do not support devices with unlocked bootloaders as they may compromise the security of our app. Thank you for understanding."
# }
# {
#   "response": "Hi Remi, we take these allegations very seriously and would like to investigate this matter further. Could you please provide us with more information on mobile.feedback@tangerine.ca? Thank you."
# }
# {
#   "response": "Hi Alex, we apologize for the inconvenience. Please try uninstalling and reinstalling the app. If the issue persists, please email us at mobile.feedback@tangerine.ca with your Orange Key and we'll investigate further. Thank you."
# }
# {
#   "response": "Hi Patrick, we're sorry to hear that you're having trouble with our app. Could you please write to us on mobile.feedback@tangerine.ca with your Orange Key? We'll do our best to help you resolve the issue. Thank you for your patience."
# }
# {
#   "response": "Hi, we apologize for the inconvenience. The Request Money feature is not available on our mobile app at the moment. However, you can access it through our website. Regarding the deposit, it usually takes up to 5 business days to process, but in some cases, it may take up to 10 business days. We apologize for any confusion caused. If you have any further questions or concerns, please feel free to email us at mobile.feedback@tangerine.ca. Thank you for your patience and understanding."
# }
# {
#   "response": "Hi Yvon, we're sorry to hear about your experience. We understand that waiting for 3-7 business days can be frustrating. However, we do have to follow certain protocols to ensure the safety and security of your transactions. If you have any specific concerns, please write to us on mobile.feedback@tangerine.ca with your Orange Key, and we'll be happy to help you out. Thank you for your feedback."
# }
# {
#     "response": "Hi Zack, we're sorry about this. Request you to write to us on mobile.feedback@tangerine.ca with your Orange Key, and we'll continue the conversation further there."
# }
# {
#     "response": "Hi Craig, we're really sorry about this. Request you to write to us on mobile.feedback@tangerine.ca with your Orange Key, as this will help us diagnose the root cause of the issue. Thank you!"
# }
# {
#     "response": "Hi Ann, we apologize for the inconvenience caused. Please write to us on mobile.feedback@tangerine.ca with your Orange Key, and we'll investigate the issue further. Thank you for your patience."
# }
# {
#   "response": "Hi Jenn, we're sorry to hear that. Could you please email us at mobile.feedback@tangerine.ca with your Orange Key and more details about the check? We'll do our best to assist you further. Thank you!"
# }
# {
#   "response": "Hi Tapash, thank you for bringing this to our attention. We apologize for the inconvenience caused. We'll definitely look into this and try to fix it as soon as possible. In the meantime, you can still log in using your password. If you have any further concerns, please feel free to email us at mobile.feedback@tangerine.ca. Thank you!"
# }
# {
#   "response": "Hi Dani, we're sorry to hear that. Could you please provide us with more details about the issues you're facing? You can write to us on mobile.feedback@tangerine.ca with your Orange Key. Thank you!"
# }
# {
#     "response": "Hi Nicola, we apologize for the inconvenience caused. The two-step verification is an added layer of security to protect your account from unauthorized access. We understand that it may be inconvenient, but it is for your own safety. Thank you for your feedback, and we hope you continue to use our services."
# }
# {
#     "response": "Hi Jason, since the void check is in PDF format, the app tries to open a corresponding PDF Viewer installed on the phone. Could you check if a PDF Reader app like Adobe Acrobat Reader is already installed on your phone? If not, could you install it and try to open the void check again? If still no luck, write to us on mobile.feedback@tangerine.ca."
# }
# {
#   "response": "Hi Tiff, thank you for your feedback. We appreciate your suggestion and will definitely take it into consideration for future updates. If you have any other feedback or concerns, please don't hesitate to reach out to us at mobile.feedback@tangerine.ca. Thank you!"
# }
# {
#   "response": "Hi Jessie, we apologize for any inconvenience caused. The available balance displayed in the app is the balance minus any pending transactions. We understand your concern and would like to assure you that we are not trying to sell overdraft protection. If you have any further questions or concerns, please feel free to email us at mobile.feedback@tangerine.ca. Thank you."
# }
# {
#   "response": "Hi Mario, thank you for your feedback. We apologize for the slow loading times you've experienced. We'll definitely take this into consideration and work on improving the app's performance. If you have any further concerns, please don't hesitate to reach out to us at mobile.feedback@tangerine.ca. Thank you!"
# }
# {
#   "response": "Hi Alexander, thank you for your feedback. We understand the importance of having the option to lock a card and we'll definitely take this into consideration for future updates. If you have any further suggestions or feedback, please feel free to email us at mobile.feedback@tangerine.ca. Thank you!"
# }
# {
#   "response": "Hi Josh, we're sorry to hear about your experience. We do require a physical address for mailing purposes, but we understand that this may not be feasible for everyone. We'll take your feedback into consideration as we continue to improve our services. If you have any further concerns, please don't hesitate to reach out to us at mobile.feedback@tangerine.ca. Thank you."
# }
# {
#   "response": "Hi Marcus, we're sorry to hear about your experience. We'd like to investigate this further. Could you please email us at mobile.feedback@tangerine.ca with your Orange Key and more details about the situation? Thank you."
# }
# {
#   "response": "Hi Cassen, we apologize for the inconvenience caused. Could you please write to us on mobile.feedback@tangerine.ca with your Orange Key? We'll investigate the issue and get back to you as soon as possible. Thank you for your patience."
# }
# {
#   "response": "Hi Joshua, we're sorry to hear that you had a bad experience with our bank. Could you please provide us with more details on what went wrong? We would like to investigate and improve our services. You can email us at mobile.feedback@tangerine.ca. Thank you."
# }
# {
#   "response": "Hi P, we're sorry to hear about your experience. We'd like to investigate this further. Could you please email us at mobile.feedback@tangerine.ca with your Orange Key and more details about the issue? Thank you."
# }
# {
#   "response": "Hi Robbie, thank you for your feedback! We're glad to hear that you find our app great. We're constantly working to improve our app and make it more comprehensive. We appreciate your suggestion and will definitely take it into consideration. If you have any other feedback or questions, please don't hesitate to reach out to us at mobile.feedback@tangerine.ca. Thank you!"
# }
# {
#     "response": "Hi Rustam, we're sorry to hear about your experience. We appreciate your feedback and will take it into consideration as we continue to improve our app. If you have any specific issues you'd like us to address, please email us at mobile.feedback@tangerine.ca with your Orange Key. Thank you."
# }
# {
#     "response": "Hi Steve, we're sorry to hear about your experience. We take customer service very seriously and would like to investigate this further. Could you please email us at mobile.feedback@tangerine.ca with your Orange Key and more details about the issue you faced? We'll do our best to resolve this for you. Thank you."
# }
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /var/folders/cq/40xd1c350qb48wl593nz7rjc0000gn/T/ipykernel_39447/1666635882.py in <module>
#      14 """
#      15
# ---> 16     response = get_completion(prompt)
#      17     print(response)
#      18     response_json = json.loads(response)
#
# /var/folders/cq/40xd1c350qb48wl593nz7rjc0000gn/T/ipykernel_39447/2212933055.py in get_completion(prompt, model)
#       4 def get_completion(prompt, model="gpt-3.5-turbo"):
#       5     messages = [{"role": "user", "content": prompt}]
# ----> 6     response = openai.ChatCompletion.create(
#       7         model=model,
#       8         messages=messages,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# --> 153         response, _, api_key = requestor.request(
#     154             "post",
#     155             url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     224             request_timeout=request_timeout,
#     225         )
# --> 226         resp, got_stream = self._interpret_response(result, stream)
#     227         return resp, got_stream, self.api_key
#     228
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     618         else:
#     619             return (
# --> 620                 self._interpret_response_line(
#     621                     result.content.decode("utf-8"),
#     622                     result.status_code,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     681         stream_error = stream and "error" in resp.data
#     682         if stream_error or not 200 <= rcode < 300:
# --> 683             raise self.handle_error_response(
#     684                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     685             )
#
# RateLimitError: That model is currently overloaded with other requests. You can retry your request, or contact us through our help center at help.openai.com if the error persists. (Please include the request ID bf9fec340e790317fd3ccf573c69377b in your message.)

# %%
for review in last_100_negative_reviews_df[(last_100_negative_reviews_df['frustration']==True) & (last_100_negative_reviews_df['anger']==True)]['topics']:
    print(review)
# Out:
# ['check differentiation', 'account lockout', 'overdraft charges', 'customer service', 'fund access']
# ['banking', 'fees', 'communication', 'wait time', 'hang-ups']
# ['2 step verification', 'notification', 'time waste', 'Scotiabank', 'banking']
# ['online banking', 'customer service', 'bank card', 'overdraft', 'switching banks']
# ['app functionality', 'password issues', 'bill payment', 'debt']

# %%
def create_link(reviewId):
    return f"""https://play.google.com/console/u/1/developers/5044239417772664106/app/4973306756359859026/user-feedback/review-details?reviewId={reviewId}&corpus=PUBLIC_REVIEWS"""
last_100_negative_reviews_df['reviews_link']= last_100_negative_reviews_df.apply(lambda x: create_link(x['reviewId']), axis=1)

# %%
# Out:
# 2     https://play.google.com/console/u/1/developers...
# 6     https://play.google.com/console/u/1/developers...
# 10    https://play.google.com/console/u/1/developers...
# 14    https://play.google.com/console/u/1/developers...
# 15    https://play.google.com/console/u/1/developers...
# Name: reviews_link, dtype: object

# %%
# import streamlit as st
# def make_clickable(url, name):
#     return st.markdown('<a href="{}" rel="noopener noreferrer" target="_blank">{}</a>'.format(url, name),unsafe_allow_html=True)

# last_100_reviews_df['reviews_link'] =last_100_reviews_df['reviews_link'].apply(lambda x: make_clickable(x, 'Google Console Link'))

# %%
last_100_negative_reviews_df.to_csv('~/Downloads/app_reviews_data_openai_last100_02052023.csv')
last_100_negative_reviews_df.head()
# Out:
#     Unnamed: 0                              reviewId                userName  \
# 2            2  09f6c653-13a0-438b-a68a-729f07d8bef5                  Cori M
# 6            6  ace86547-4b08-4902-b8a3-c6331b8da4f2  Jan-Adam Van Der Henne
# 10          10  46b21506-ab5d-4be0-b665-9990d7fe17a4              kevin Hord
# 14          14  ca0a1d57-10c2-4bf1-b49e-6a124b79287c               Melly Mel
# 15          15  62583d51-7154-4274-9966-b162f904e269               Alex Pike
#
#                                             userImage  \
# 2   https://play-lh.googleusercontent.com/a-/ACB-R...
# 6   https://play-lh.googleusercontent.com/a-/ACB-R...
# 10  https://play-lh.googleusercontent.com/a-/ACB-R...
# 14  https://play-lh.googleusercontent.com/a/AGNmyx...
# 15  https://play-lh.googleusercontent.com/a-/ACB-R...
#
#                                               content  score  thumbsUpCount  \
# 2   The "pending transactions" for my credit card ...      2              0
# 6   the amount of devices supported by this app is...      2              0
# 10   Just about as bad as my branch, terribly spotty.      2              0
# 14  could improve on the technical side that other...      1              0
# 15  So the app updated yesterday and now the app d...      3              0
#
#    reviewCreatedVersion                   at replyContent  ... month  \
# 2                   NaN  2023-05-01 11:56:14          NaN  ...     5
# 6               20.48.0  2023-04-30 23:49:47          NaN  ...     4
# 10              20.48.0  2023-04-30 14:26:17          NaN  ...     4
# 14              20.48.0  2023-04-30 08:41:32          NaN  ...     4
# 15              20.49.1  2023-04-29 23:32:14          NaN  ...     4
#
#    repliedbool                                            summary  sentiment  \
# 2        False         Pending transactions disappear upon login.   negative
# 6        False   Request for app to be available on more devices.   negative
# 10       False                    The app is terrible and spotty.   negative
# 14       False  Reviewer suggests technical improvements and c...   negative
# 15       False                   App update causing startup issue   negative
#
#                                        emotions  anger frustration  \
# 2                                 [frustration]  False        True
# 6                 [disappointment, hopefulness]  False        True
# 10                             [disappointment]  False        True
# 14  [disappointment, frustration, indifference]  False        True
# 15                     [frustration, confusion]  False        True
#
#                                                topics  \
# 2          [credit card, pending transactions, login]
# 6                  [device support, app availability]
# 10                                 [app, performance]
# 14  [technical, online banking, mobile app, functi...
# 15  [app update, startup issue, bug fix, Scotia sy...
#
#                                       review_response  \
# 2   Hello Cori, we apologize for the inconvenience...
# 6   Hello Jan-Adam, thank you for your feedback. W...
# 10  Hello Kevin, we're sorry to hear that you had ...
# 14  Hello Melly, thank you for your feedback. We a...
# 15  Hello Alex, we apologize for the inconvenience...
#
#                                          reviews_link
# 2   https://play.google.com/console/u/1/developers...
# 6   https://play.google.com/console/u/1/developers...
# 10  https://play.google.com/console/u/1/developers...
# 14  https://play.google.com/console/u/1/developers...
# 15  https://play.google.com/console/u/1/developers...
#
# [5 rows x 24 columns]
